# %%
import pandas as pd

# %%
from flaskblog.models import Student
from flaskblog import db
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from flaskblog.models import Student
#       2 from flaskblog import db
#
# File c:\D\Project\ProjectTHPT2023demo\BackEnd\flaskblog\__init__.py:11
#       8 app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///site.db'
#       9 db = SQLAlchemy(app)
# ---> 11 from flaskblog import routes
#
# File c:\D\Project\ProjectTHPT2023demo\BackEnd\flaskblog\routes.py:4
#       1 from flask import  render_template ,redirect,url_for
#       3 from flaskblog import app
# ----> 4 from flaskblog.forms import Search , LoginForm
#       5 from flaskblog.models import Student
#       6 from flask_login import login_user , current_user
#
# File c:\D\Project\ProjectTHPT2023demo\BackEnd\flaskblog\forms.py:4
#       2 from wtforms import StringField , PasswordField , SubmitField , BooleanField
# ...

# %%
df = pd.read_csv('C:/D/Project/ProjectTHPT2023demo/GettingData/datathpt2022f.csv')
df
# Out:
#              SBD  Toán   Văn    Sử   Địa    Lí   Hóa  Sinh  Ngoại ngữ  GDCD
# 0       10000001   5.2  5.00  5.00  5.25   NaN   NaN   NaN        NaN   NaN
# 1       10000002   9.2  6.50   NaN   NaN  7.50  6.75  8.25        8.6   NaN
# 2       10000003   9.0  7.75   NaN   NaN  6.75  6.00  3.75        8.2   NaN
# 3       10000004   8.8  8.50   NaN   NaN  6.75  9.00  8.75        9.0   NaN
# 4       10000005   8.0  9.00  9.75  8.75   NaN   NaN   NaN        8.2  8.25
# ...          ...   ...   ...   ...   ...   ...   ...   ...        ...   ...
# 995436  64006584   8.4  6.75  6.50  6.75   NaN   NaN   NaN        4.6  9.00
# 995437  64006585   5.6  6.50  6.25  6.75   NaN   NaN   NaN        2.8  8.50
# 995438  64006586   5.8  6.00  7.25  8.00   NaN   NaN   NaN        6.6  8.00
# 995439  64006587   7.6  6.75  8.75  7.25   NaN   NaN   NaN        7.0  9.75
# 995440  64006588   6.6  4.50  3.00  6.00   NaN   NaN   NaN        3.2  7.50
#
# [995441 rows x 10 columns]

# %%
for index , data in df.iterrows() :
    student = Student(SBD = int(data['SBD']) , Toán = data['Toán'] , Van = data['Văn'] , Su = 'Sử' , Dia = data['Địa'] , 
                      Li = data['Lí'] , Hoa = data['Hóa'] , Sinh = data['Sinh'] , NN = data['Ngaoij ngữ'] , GDCD = data['GDCD'])
    db.session.add(student)
    db.session.commit()
# Out:
# 10000001.0
# 10000002.0
# 10000003.0
# 10000004.0
# 10000005.0
# 10000006.0
# 10000007.0
# 10000008.0
# 10000009.0
# 10000010.0
# 10000011.0
# 10000012.0
# 10000013.0
# 10000014.0
# 10000015.0
# 10000016.0
# 10000017.0
# 10000018.0
# 10000019.0
# 10000020.0
# 10000021.0
# 10000022.0
# 10000023.0
# 10000024.0
# 10000025.0
# 10000026.0
# 10000027.0
# 10000028.0
# 10000029.0
# 10000030.0
# 10000031.0
# 10000032.0
# 10000033.0
# 10000034.0
# 10000035.0
# 10000036.0
# 10000037.0
# 10000038.0
# 10000039.0
# 10000040.0
# 10000041.0
# 10000042.0
# 10000043.0
# 10000044.0
# 10000045.0
# 10000046.0
# 10000047.0
# 10000048.0
# 10000049.0
# 10000050.0
# 10000051.0
# 10000052.0
# 10000053.0
# 10000054.0
# 10000055.0
# 10000056.0
# 10000057.0
# 10000058.0
# 10000059.0
# 10000060.0
# 10000061.0
# 10000062.0
# 10000063.0
# 10000064.0
# 10000065.0
# 10000066.0
# 10000067.0
# 10000068.0
# 10000069.0
# 10000070.0
# 10000071.0
# 10000072.0
# 10000073.0
# 10000074.0
# 10000075.0
# 10000076.0
# ...
